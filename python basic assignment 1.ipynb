# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello' = string
# -87.8   = float
# -       = mathematical operator for subraction
# /       = mathematical operator for divison which returns numerator
# +       = mathematical operator for addition
# 6       = integer
#
# 2. What is the difference between string and variable?
#
#    . string is a datatype which contains collection of characters or integers or float obejects which are enclosed in a double quote or singe quote for example ('ineuron 1' or "ineuron 2.0" )
#
#     . variable is a name which is given to a datatype . we can declare anyname to a variable and can declare a value to it.
#
#     . for example( a = "ineuron" where 'a' is variable which is assigned with value "ineuron" which is string datatype.
#
#    .  we cannot use some predefined keywords as a variable.
#
#
# 3. Describe three different data types.
#
#     1.string is a datatype which contains collection of characters or integers or float obejects which are enclosed in a double quote or singe quote for example ('ineuron 1' or "ineuron 2.0" )
#
#     2.integer is a datatype which can have only real numbers for example(0,1,2,3,4)
#
#     3.float is a datatype which can have numbers with decimal values for example ( 1.5, 2.3, 4.9)
#
#
#
# 4. What is an expression made up of? What do all expressions do?
#
#    . expression is a instruction statement which is made up of operator or value or computation statement which is used for evaluvation. all expressions make some computation works and gives a value.
#
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#    . spam = 10 is a assignment satement which only assign's the value 10 in the variable spam and doest not perform any operation and does not return a value where as in expression when it is executed it will return a value.
#
#
# 6. After running the following code, what does the variable bacon contain?
#
# bacon = 22
# bacon + 1
#
# the value will be still '22' if it is coded as "bacon= bacon + 1" then the output will be 23.
#
# 7. What should the values of the following two terms be?
#
# 'spam' + 'spamspam' = 'spamspamspam'
# 'spam' * 3 = 'spamspamspam'
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
#     .eggs is just a word which can be used a valid variable and it does not belong to any predefined keyword so it is valid where as 100 is a realnumber and numbers cannot be used as a variable unless it is used in combination of some alphabets for example if we declare as a100=100 then a100 is a valid variable.
#
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
#     .to get integer version of a value we can use this expression   " variable=int(value) "
#     .to get floating-point version of a value we can use this expression " variable=float(value) "
#     .to get string version of a value we can use this expression " variable=str(value) "
#
#
# 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten ' + 99 + ' burritos.'
#
#    . it will show concatenation error  because it has different datatypes. to fix this error we need all values in same datatypes. we can change datatype of value and this is called typecasting.
#
# the error can be fixed by concatenating the interger value in to string value and below code will fix this error
#
# 'I have eaten ' + str('99') + ' burritos.'
